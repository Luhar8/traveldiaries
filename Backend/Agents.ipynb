# %%
from duckduckgo_search import DDGS
import re
import os
import pyttsx3

from groq import Groq
if os.getenv("GROQ_API_KEY") is None:
    os.environ["GROQ_API_KEY"] = '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'

    
from llama_index.llms.ollama import Ollama
from llama_index.core import SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.node_parser import TokenTextSplitter
from llama_index.core.ingestion import IngestionPipeline
from llama_index.core import VectorStoreIndex
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings
from llama_index.core import StorageContext, load_index_from_storage

#from llama_index.embeddings.openai import OpenAIEmbedding
import os

import whisper
from langdetect import detect
from pytube import YouTube


import tempfile

#_________________________________________________________________________________________________________________

#Youtube Search Video RAG with Vector DB

def startfile(fn):
    os.system('open %s' % fn)

def create_and_open_txt(text, filename):
    # Create and write the text to a txt file
    with open(filename, "w") as file:
        file.write(text)
    startfile(filename)


def delete_audio_file(file_path):
    try:
        os.remove(file_path)
        print(f"Audio file {file_path} deleted successfully.")
    except OSError as e:
        print(f"Error deleting audio file: {e}")

    
def youtube_audio_text(url, path):
    yt = YouTube(url)
    audio_stream = yt.streams.filter(only_audio=True).first()
    
    output_path = path #r"C:\Users\akhil\Downloads\YoutubeAudios"
    filename = "audio.mp3"
    audio_stream.download(output_path=output_path, filename=filename)

    print(f"Audio downloaded to {output_path}\{filename}")

    model = whisper.load_model("base")
    result = model.transcribe(path + "\\audio.mp3")
    transcribed_text = result["text"]
    #print(transcribed_text)

    # language = detect(transcribed_text)
    # print(f"Detected language: {language}")
    delete_audio_file(path + "\\audio.mp3")
    
    create_and_open_txt(transcribed_text, path + "\\output_Text.txt")


def Youtube_RAG(model, path):
    llm = Ollama(model="mistral", request_timeout=30.0)

    #inp = input("enter 1 - Hugging Face Embedding \n2 - OpenAI Embedding")
    inp = 1
    if inp == 1:
        #
        Settings.embed_model = HuggingFaceEmbedding(model_name="flax-sentence-embeddings/all_datasets_v4_MiniLM-L6")


    #Settings.llm = Ollama(model="mistral", request_timeout=200.0)
    Settings.llm = Ollama(model=model, request_timeout=200.0)
    
    documents = SimpleDirectoryReader(path).load_data()
    sen_split=TokenTextSplitter()
    pipeline = IngestionPipeline(
        transformations=[sen_split]
    )
    nodes=pipeline.run(show_progress=True,documents=documents, in_place=True)
    index = VectorStoreIndex.from_documents(
        documents, transformations=[sen_split]
    )
    index.storage_context.persist(persist_dir="./indexDB")
    storage_context = StorageContext.from_defaults(persist_dir="./indexDB")
    index = load_index_from_storage(storage_context)
    query_engine = index.as_query_engine()
    response = query_engine.query("Summary of the Document")
    print(response)
    return response
    
#     while True:
#         #
#         user_input = input("Enter 'stop' to end: ")
#         if user_input.lower() == 'stop':
#             print("Stopping the loop.")
#             break
#         else:
#             response = query_engine.query(user_input)
#             print()
#             print(response)
        

def youtube(url):
    path = tempfile.mkdtemp()
#     path = "C:\\Users\\akhil\\Downloads\\YOUTUBE_VIDEO_SCRPT_WRITTER\\Folder"
    #url = input("Enter the YouTube video URL: ")
    youtube_audio_text(url, path)
    #model_id = input("Enter the model you want to use: 1 - Mistral, 2- Codellama 13B, 3 - llava")
    model_id = 1
    if model_id == 1:
        response = Youtube_RAG("mistral", path)
    elif model_id == 2:
        response = Youtube_RAG("codellama:13b", path)
#     elif model_id == 3:
#         Youtube_RAG("codellama:13b")
    return response

#_________________________________________________________________________________________________________________
    
    
#Not using Groq Max Tokens Completed for Today
def O_LLM(query):
    client = Groq(
        api_key=os.environ.get("GROQ_API_KEY"),
    )

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": query,
            }
        ],
        model="mixtral-8x7b-32768",
        #model="gemma-7b-it",
        temperature = 0,
    )

    response = chat_completion.choices[0].message.content
    return response


import google.generativeai as genai

#Gemini 1.0 pro, good not great need to test on 1.5 pro in google hackathon
def O_LLM_(query):
    Gemini_API = "AIzaSyATwhUa9DSZrCAphxwHXPLEHWCZ-IDptT8"
    model = genai.GenerativeModel('gemini-pro')
    genai.configure(api_key=Gemini_API)
    response = model.generate_content(query)
    resp = response.text
   # print(response.text)
    return resp



def extract_thoughts_actions_output(text):
    thoughts = []
    actions = []
    outputs = []

    thought_pattern = r'Thought \d+:\s*(.*)'
    action_pattern = r'Action \d+:\s*(.*)'
    output_pattern = r'Output \d+:\s*(.*)'

    # Extract Thoughts, Actions, and Output
    thoughts = re.findall(thought_pattern, text)
    actions = re.findall(action_pattern, text)
    outputs = re.findall(output_pattern, text)

    return thoughts, actions, outputs

def extract_info(texts):
    """
    This function extracts tools and inputs from a list of text strings.

    Args:
      texts: A list of strings containing instructions with tools and inputs in brackets.

    Returns:
      A dictionary where keys are tools (e.g., "Search", "Summarize", "Calculate") 
      and values are corresponding inputs (e.g., "funding received by Mistral Ai from investors").
    """
    tools = {}
    for text in texts:
        # Extract tool using regular expression
        tool = re.findall(r'^\w+', text)[0]

        # Extract input using regular expression
        inp = re.findall(r'\[(.*?)\]', text)[0]

        # Add tool and input to the dictionary
        tools[tool] = inp
    return tools



def duck_go(Keyword):
    results = DDGS().text(Keyword, max_results=10)
    bodies = [item['body'] for item in results]
    paragraph = ' '.join(bodies)
    return paragraph

def Calculate(expression):
    print(f"Calculating: {expression}")

    
import subprocess

def execute_python(code):
    #print("Code recieved for execution Terminal: ",code)
    result = subprocess.run(["python", "-c", code], capture_output=True, text=True)
    err = 0
    # Check if there's an error
    if result.returncode != 0:
        print("Error Found")
        err = 1
        return result.stderr, err
    else:
        
        output = result.stdout
        return output, err

#------------------------------------------------------------------------------------------------
def extract_text(input_string, option):
    if option == 1:
        pattern = r'\```python(.*?)\```'
        matches = re.search(pattern, input_string, re.DOTALL)
        if matches:
            return matches.group(1).strip()
        else:
            return None
    else:
        pattern = r'\```(.*?)\```'
        matches = re.search(pattern, input_string, re.DOTALL)
        if matches:
            return matches.group(1).strip()
        else:
            return None
#------------------------------------------------------------------------------------------------
def check_substring(main_string, substring):

    if substring.lower() in main_string.lower():
        return True
    else:
        return False
#------------------------------------------------------------------------------------------------
Error_Counter = 0

def code_processing(answer):
    #answer = O_LLM(query)
    main_string = answer
    substring = "```python"
    substring_sub = "```"
    print("\n\n")
    if check_substring(main_string, substring_sub):
        #print("```, FOUND PREPROCESSING... ")
        
        if check_substring(main_string, substring):
            #print("```python, FOUND PREPROCESSING... ")
            input_string =  answer
            extracted_text = extract_text(input_string, 1)
            
            if extracted_text:
                answer = extracted_text
                #print("Extracted Text: \n", answer)
                code = answer
            else:
                #print("No text found between ``` and ```.")
                code = answer
        else:
            print("")
            if check_substring(main_string, substring_sub):
                print("```python, FOUND PREPROCESSING... ")
                input_string =  answer
                extracted_text = extract_text(input_string, 0)

                if extracted_text:
                    answer = extracted_text
                    #print("Extracted Text: \n", answer)
                    code = answer
                else:
                    print("No text found between ``` and ```.")
                    code = answer
            
    else:
        print("```python ,NOT FOUND")
        code = answer
    print("Code Extracted: ",code)
    code_to_execute = code    
    result, err = execute_python(code_to_execute)
    if err == 0:
        print("Returning Result to Prompt: ", result)
        Error_Counter = 0
        return result
    else:
        Code_error_recur(code_to_execute, result)

        

def Code_error_recur(code_to_execute, result):
    Error_Counter = Error_Counter + 1
    Error_query = "Code: " + code_to_execute + "\n Error: " + result + "\n Dont add any comments and always write code under these tags '```python' and '```' " 
    resp = O_LLM(Error_query)
    code_processing(resp)

    

def calculate(expression):
    try:
        result = eval(expression)
        return result
    except Exception as e:
        return f"Error: {str(e)}"
    
    

def Voice(voice_response):
    text = voice_response
    engine = pyttsx3.init()
    engine.setProperty('rate', 190)    # Speed percent (can go over 100)
    engine.setProperty('volume', 0.9)  # Volume 0-1
    engine.say(text)
    engine.runAndWait()
    return "Speaking completed"

    
#Afterwards Update match with elif

def handle_request(data, thought):
    #
    if "Search" in data:
        output = duck_go(data["Search"])
        param = data["Search"]
#         print("In DuckDuckGo Search Question:",thought)
#         print("Output from search:", output)
        prompt = f"Consider yourself as a professional web researcher and Summarize the text based on your task assignmed by boss in plain text with space formating: {thought}\n\n\n Text: {output}"
        output = O_LLM(prompt)
        return output
    elif "Calculator" in data:
        output = Calculate(data["Calculate"])
        return output
    elif "Python" in data:
        output = code_processing(data["Python"])
        return output
    elif "Voice" in data:
        output = Voice(data["Voice"])
        return output
    elif "Youtube" in data:
        output = youtube(data["Youtube"])
        return output
    elif "Human" in data:
        output = input(data["Human"])
        return output

    else:
        print("Invalid key. Please use 'Search' or 'Calculate'")

        
def convert_list_to_dict(data):
    result = {}
    for item in data:
        try:
            key, value = item.split('[', 1)
            value = value.rsplit(']', 1)[0].strip()  # Get text from beginning to last ']'
            if value:  # Check if value is not empty (null)
                result[key.strip()] = value
        except ValueError:
            continue  # Skip to the next iteration if splitting fails
    return result

#extract_thoughts_actions_output not using, new function extract_actions is better!
def extract_thoughts_actions_output(text):
    print(text)
    thoughts = []
    actions = []
    outputs = []

    thought_pattern = r'Thought \d+:\s*(.*)'
    action_pattern = r'Action \d+:\s*([\s\S]*?)(?=(?:Thought \d+|$))'
    output_pattern = r'output:\s*(.*)'

    # Extract Thoughts, Actions, and Output
    thoughts = re.findall(thought_pattern, text, re.IGNORECASE)
    action_matches = re.findall(action_pattern, text, re.IGNORECASE)
    print("actio_match:", action_matches)
    actions = ['\n'.join(action.strip().split('\n')) for action in action_matches]
    outputs = re.findall(output_pattern, text, re.IGNORECASE)

    return thoughts, actions, outputs

def extract_actions(text):
    pattern = r'[Aa]ction(?:[:\s\d]+)?\s*([^\[\]]+\[[^\[\]]+\])'
    matches = re.findall(pattern, text)
    return matches

def token_count(text):
    tokens = text.split()
    num_tokens = len(tokens)
    return num_tokens


def actions_perform(resp,thought):
    actions_list = extract_actions(resp)
    output_list = []
    for i in actions_list:
        i = [i]
        actions_tools_dic = convert_list_to_dict(i)
        print("Action Tools Found: (List) ",actions_tools_dic)
        print(type(actions_tools_dic))
        out = handle_request(actions_tools_dic, thought)
        output_list.append(out)
        
    output = " ".join(output_list)
    return output



def summary_context(text):
    context_len = token_count(text)
    print("Token Length: ",context_len)
    if context_len > 250:
        summm_prompt = f"""
        Your a Editor working in a company AGNOS, your task is to summarize the text given by your manager. You have to perform this job carefully as the company development is dependent on your work. 
        Now summarize this text without loosing any important information, which may include, numbers, values, names, strategies, list or nested lists or any other. 
        You can delete any matter if it doesn't belongs to the context your working.
        You cannot rewrite the summary once writen so carefully do the work. All the best.

        Text:
        {text}
        """
        text = O_LLM(summm_prompt)
    return text
# Out:
# C:\Users\akhil\anaconda3\envs\OpenAI_Langchain\lib\site-packages\transformers\utils\hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
Task = "A client plans from USA want to go India for vacation for 10 days and have budget of $4000, they are couple, add some romatic places or food " #, and give me day by day attraction plan"


Example_prompt_thoughts = """
Consider yourself a manager at a company called AGNOS Travel Agency, and break down this complex task from your boss (for travelling clients) into multiple simple tasks as thoughts for your assistant to complete. Don't respond to any other tools except these, as they are new and cannot be used other than these: 

Tools available to use: Search[Text or URL to search in the internet]

Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand

Thought 1: First I need to find, which companies work in luxury shoe market in internet
Thought 2: Second, Make a list of all the companies
Thought 3: Third, Now search which products, Number of products, revenue, SWOT analysis of each company listed
Thought 4: Fourth, Now With all the companies information write a important summary
Thought 5: With all the information, I need to find where can we build new shoe brand without much competation 

Perform search one by one
"""


Task_promp_thoughts = f"""{Example_prompt_thoughts}
Task: {Task}

Now write simple multiple Thoughts for this Task and use only tools mentioned. Write Thoughts for this task below and Dont write any actions its not your work to perform.
"""


print(Task_promp_thoughts)



Example_prompt_Actions = """
You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands. 

He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
Thought 1: First I need to find, which companies work in luxury shoe market
Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024" 
Thought 2: Second, Make a list of all the companies
1. Stuart Weitzman
2. Jimmy Choo shoes
3. Alexander McQueen
4. Valentino shoe
Thought 3: Third, Now search which products, Number of products. 
Action: Search[Stuart Weitzman shoes all products]  

Completed.

"""
# Out:
# Consider yourself a manager at a company called AGNOS Travel Agency, and break down this complex task from your boss (for travelling clients) into multiple simple tasks as thoughts for your assistant to complete. Don't respond to any other tools except these, as they are new and cannot be used other than these:
#
# Tools available to use: Search[Text or URL to search in the internet]
#
# Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
#
# Thought 1: First I need to find, which companies work in luxury shoe market in internet
# Thought 2: Second, Make a list of all the companies
# Thought 3: Third, Now search which products, Number of products, revenue, SWOT analysis of each company listed
# Thought 4: Fourth, Now With all the companies information write a important summary
# Thought 5: With all the information, I need to find where can we build new shoe brand without much competation
#
# Perform search one by one
#
# Task: A client plans from USA want to go India for vacation for 10 days and have budget of $4000, they are couple, add some romatic places or food
#
# Now write simple multiple Thoughts for this Task and use only tools mentioned. Write Thoughts for this task below and Dont write any actions its not your work to perform.

# %%
import markdown2
import pdfkit

Markdown_full_text = " "

def Markdown_pdf(markdown_text, output_path):
    global Markdown_full_text
    Markdown_full_text = markdown_text
    
    html_text = markdown2.markdown(markdown_text)
    print("==================START=======================")
    print(markdown_text)
    print("===================END========================")

    pdfkit.from_string(html_text, output_path)
    
def To_do_list(text):
    thoughts = re.findall(r'(?i)(?<=thought\s)\d+:\s(.+)', text)
    return thoughts

thoughts_resp = O_LLM(Task_promp_thoughts)
thoughts_resp = thoughts_resp.replace('*', '')
print(thoughts_resp)

thoughts_list = To_do_list(thoughts_resp)
thoughts_list.append(f"With all the information give me a report for the task: {Task}")
print(thoughts_list)


#------------------------------------------------------------------------------------------------------

Action_prompt = f"""
Task: {Task}
Thought : {thoughts_list[0]}
"""

Action_disclaimer = " Write search Thought one by one .Write an simple Action for this Thought with correct syntax"

Markdown_prompt_editor = """
Your a Editorial Manager in AGNOS Business solutions. Name 'Tillu', where you need to provide a summary report report to your client regrading their request. 
Here is the final draft of the report, try to build some hidden insights from this and write it in final report, write this draft into beautiful markdown, if already in markdown, try to make it better and clear.
And in final write your opinion in paragraph. Make the report better and bigger.
"""
OBSERVATIONS = []
i = 0
for i in range(len(thoughts_list)):
    print(f"------------ITEARATION {i}------------------")
    if i > 0: 
        try:
            Action_prompt = Action_prompt + "Observation: " + observation
        except Exception as e:
            observation = " "
            Action_prompt = Action_prompt + "Observation: " + observation
            
        Action_prompt = summary_context(Action_prompt)
        Action_prompt = f"{Action_prompt}\n Thought : {thoughts_list[i]} "

    Action_prompt_full = f"{Example_prompt_Actions}\n {Action_prompt} \n {Action_disclaimer} "
    print("********************FULL-PROMPT-START********************")
    print(Action_prompt_full)
    print("********************FULL-PROMPT-END********************")
    print("\n\n")
    Action_resp = O_LLM(Action_prompt_full)
    Action_resp = Action_resp.replace('*', '')
    print(Action_resp)
    try:
        observation = actions_perform(Action_resp,thoughts_list[i])
        OBSERVATIONS.append(observation)
        print(observation)
    except Exception as e:
        print(e)
        observation = " "
    
    itr = len(thoughts_list)
    if i == (itr-1):
        Markdown_prompt_full = f"{Markdown_prompt_editor} \n Draft: {Action_prompt} \n {observation} {OBSERVATIONS}"
        
        fn_output_path = r'C:\Users\akhil\Downloads\Final_report_rahul_agency_couple_india.pdf'
        
        final_report = O_LLM(Markdown_prompt_full)
        Markdown_pdf(final_report,fn_output_path)
        
        ob_output_path = r'C:\Users\akhil\Downloads\Final_Observations_agency_couple_india.pdf'
        
        OBSERVATIONS = " ".join(OBSERVATIONS)
        Markdown_pdf(OBSERVATIONS,ob_output_path)
# Out:
# Thought 1: First, find popular romantic places and food options in India for a couples' vacation.
# Thought 2: Use the search tool to look up "romantic places in India" and "famous Indian cuisine for couples."
# Thought 3: Make a list of the top romantic places and Indian food options that I find in the search results.
# Thought 4: Next, search for general travel information and budget-friendly options in India, using search terms like "10-day itinerary in India" and "budget travel tips for India."
# Thought 5: Consider the client's budget of $4000 and the costs of travel, accommodations, and activities at the romantic locations. Make sure to find cost-effective options that fit within their budget.
# Thought 6: With the information gathered, create a 10-day itinerary for the couple, including romantic places, food experiences, and travel tips, while keeping their budget in mind.
# ["First, find popular romantic places and food options in India for a couples' vacation.", 'Use the search tool to look up "romantic places in India" and "famous Indian cuisine for couples."', 'Make a list of the top romantic places and Indian food options that I find in the search results.', 'Next, search for general travel information and budget-friendly options in India, using search terms like "10-day itinerary in India" and "budget travel tips for India."', "Consider the client's budget of $4000 and the costs of travel, accommodations, and activities at the romantic locations. Make sure to find cost-effective options that fit within their budget.", 'With the information gathered, create a 10-day itinerary for the couple, including romantic places, food experiences, and travel tips, while keeping their budget in mind.', 'With all the information give me a report for the task: A client plans from USA want to go India for vacation for 10 days and have budget of $4000, they are couple, add some romatic places or food ']
# ------------ITEARATION 0------------------
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#
# Task: A client plans from USA want to go India for vacation for 10 days and have budget of $4000, they are couple, add some romatic places or food
# Thought : First, find popular romantic places and food options in India for a couples' vacation.
#
#   Write search Thought one by one .Write an simple Action for this Thought with correct syntax
# ********************FULL-PROMPT-END********************
#
#
#
# Thought 1: Search for popular romantic places in India for couples.
# Action: Search[Romantic places in India for couples]
#
# Thought 2: Find out more information about the top romantic places in India.
# Action: Search[Information about (top romantic places in India from search results)]
#
# Thought 3: Search for popular romantic food options in India for couples.
# Action: Search[Romantic food in India for couples]
#
# Thought 4: Look for any popular romantic activities or experiences in India for couples.
# Action: Search[Romantic activities or experiences in India for couples]
#
# (Note: After each search, you will want to review the results and identify the most suitable options for the client based on their preferences and budget.)
# Action Tools Found: (List)  {'Search': 'Romantic places in India for couples'}
# <class 'dict'>
# C:\Users\akhil\anaconda3\envs\OpenAI_Langchain\lib\site-packages\curl_cffi\aio.py:39: RuntimeWarning:
#     Proactor event loop does not implement add_reader family of methods required.
#     Registering an additional selector thread for add_reader support.
#     To avoid this warning use:
#         asyncio.set_event_loop_policy(WindowsSelectorEventLoopPolicy())
#
#   warnings.warn(PROACTOR_WARNING, RuntimeWarning)
# Action Tools Found: (List)  {'Search': 'Information about (top romantic places in India from search results)'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': 'Romantic food in India for couples'}
# <class 'dict'>
# C:\Users\akhil\anaconda3\envs\OpenAI_Langchain\lib\site-packages\curl_cffi\aio.py:205: UserWarning: Curlm alread closed! quitting from process_data
#   warnings.warn("Curlm alread closed! quitting from process_data")
# Action Tools Found: (List)  {'Search': 'Romantic activities or experiences in India for couples'}
# <class 'dict'>
# For a couples' vacation in India, popular romantic places include:
#
# 1. Kanyakumari, Tamil Nadu - known for its stunning sunsets and full-moon sightings.
# 2. Gangtok, Sikkim - offering a variety of tour packages for couples.
# 3. Andaman & Nicobar - famous for its serene beaches and water sports activities.
# 4. Nainital, Uttarakhand - with pleasant weather and scenic landscapes.
# 5. Manali, Himachal Pradesh - offering romantic drives and breathtaking views.
# 6. Jammu & Kashmir - a hot spot for romantic getaways with serene lakes and scenic landscapes.
# 7. Goa - known for its hippy culture, incredible cuisine, and exotic beaches.
# 8. Masinagudi, Tamil Nadu - offering wilderness retreats and exhilarating getaways.
# 9. Gulmarg, Jammu & Kashmir - an ideal setting for couples seeking a cosy winter retreat.
#
# Popular food options for couples in India:
#
# 1. Seafood in Goa.
# 2. Momos and Thukpa in Sikkim.
# 3. Kawah in Kashmir.
# 4. Chole Bhature in North India.
# 5. Dosas and Idlis in South India.
# 6. Biryani in Hyderabad.
# 7. Litti Chokha in Bihar.
# 8. Pitha in Assam.
# 9. Vada Pav in Mumbai. For a couples' vacation in India, consider the following romantic places and food options:
#
# 1. Kanyakumari, Tamil Nadu - Visit during a full moon to see the sunset and moonrise together. Check out Tsomgo Lake, Nathu La Pass, Tiger Hill, and the tea gardens.
#
# 2. Manali, India - Take a romantic drive through the Himalayan mountains.
#
# 3. Jammu & Kashmir - Visit the Kashmir Valley for regal charm and breathtaking landscapes.
#
# 4. Gangtok - This versatile hill station offers attractions like Ban Jhakri Falls Park, Gangtok Ropeway, Jawaharlal Nehru Botanical Garden, Sikkim Himalayan Zoological Park, and M.G. Marg.
#
# 5. Tawang - This small city in Arunachal Pradesh boasts attractions like Sela Pass, Madhuri Lake, Tawang Buddhist Monastery, and Nuranang Falls.
#
# 6. Kerala - Explore the backwaters and beaches, and stay at a Treebo Hotel in Alleppey.
#
# 7. Coorg, Karnataka - Go on a special jungle safari to spot exotic animals.
#
# 8. Lakshadeep - Visit this surreal and romantic destination for lush greenery, tranquil lagoons, and sun-drenched beaches.
#
# Food options:
# - Kashmiri cuisine, known for its rich and mildly spicy dishes.
# - Tawang offers Tibetan and Chinese cuisine.
# - Kerala's backwaters are famous for seafood.
# - Coorg is known for its spicy pork curries and bamboo shoot dishes.
# - Lakshadeep offers traditional Indian and Arabic cuisine.
#
# Airport: Leh airport is the nearest air link for the Ladakh region.
#
# Land Package for Honeymoon: Starting from INR 10,000 per person. For a couples' vacation in India, there are several romantic places to visit and delicious food options to try. Here are some popular cafes and restaurants:
#
# 1. Koi Bar, St Regis, Lower Parel: This bar offers a luxurious escape with Pisco cocktails, a high ceiling, plush sofas, and sprawling views of the city. The menu includes an expansive range of dishes, from burgers and pastas to fresh seafood and tacos.
#
# 2. The Fisherman's Wharf, Goa: This beachside restaurant offers shaded and comfortable seating, with a menu that caters to every kind of craving. Try their tikis and barrel-aged drinks.
#
# 3. The Flying Elephant, Chennai: Located in the Taj Club House Hotel, this restaurant offers Lebanese, Mediterranean, Spanish, and Moroccan cuisine. Must-try dishes include Cheese Cigar Rolls and Mushroom Ravioli.
#
# 4. La Piazza, New Delhi: Known for serving the best pepperoni pizza in India.
#
# 5. Baluchi, New Delhi: Located in The Lalit hotel, this restaurant offers North Indian cuisine.
#
# 6. Savannah Bar, Mumbai: This bar has an outstanding ambiance and friendly staff.
#
# 7. Ambrai Restaurant, Udaipur: Located on the banks of Lake Pichola, this restaurant offers a romantic dining experience with a view of well-lit temples and palaces.
#
# 8. CIBO House HITEC City, Hyderabad: This popular restaurant serves delicious Italian cuisine, including pizzas, pastas, salads, sandwiches, and desserts.
#
# 9. Holy Basil, Hyderabad: This casual dining restaurant specializes in Asian Chinese cuisine, including hot pot, bao, dimsums, and Thai green curry.
#
# If you're looking for a romantic getaway, consider Gangtok, Sikkim, which offers a 4-day tour of the city and its surrounding areas. For a honeymoon destination, consider the 5-night/6-day Darjeeling Gangtok Honeymoon Package or the 6-night/7-day Darjeeling Gangtok Pelling Tour. India has several popular romantic places for a couples' vacation, including:
#
# 1. Gangtok, Sikkim - known for its tea gardens, Tsomgo Lake, Nathu La Pass, and romantic drives. There are several tour packages available for 3 to 7 days.
# 2. Udaipur, Shimla, Jaipur, Munnar, and Gulmarg are the top 5 romantic places in India, each offering a unique blend of history, natural beauty, and romantic ambiance.
# 3. Goa, Kerala, Rajasthan, the Andaman and Nicobar Islands, and Himachal Pradesh are the most popular honeymoon places in India.
# 4. Kanyakumari, Tamil Nadu, is a great place for couples, with romantic sunsets and the moon rising.
# 5. Andaman and Nicobar Islands are perfect for a romantic gateway, with crystal blue water and scenic beaches.
# 6. Other romantic destinations in India include Alleppey, Goa, Shimla & Munnar, and Pondicherry.
#
# Food options for couples in India include a variety of local and international cuisines. In Gangtok, couples can try Sikkimese and Tibetan cuisine, while in Goa, they can enjoy fresh seafood and Goan cuisine. In Kerala, couples can try traditional dishes like dosa, idli, and vada, while in Rajasthan, they can try Rajasthani thali and laal maas. In the Andaman and Nicobar Islands, couples can try fresh seafood and local dishes like fish curry and coconut-based dishes.
#
# Overall, India offers a wide range of romantic places and food options for a memorable couples' vacation.
# ------------ITEARATION 1------------------
# Token Length:  970
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#  A client plans to vacation in India for 10 days with a budget of $4000. This summary aims to provide romantic places and food options for their trip.
#
# Popular romantic places in India:
#
# 1. Kanyakumari, Tamil Nadu
# 2. Gangtok, Sikkim
# 3. Andaman & Nicobar
# 4. Nainital, Uttarakhand
# 5. Manali, Himachal Pradesh
# 6. Jammu & Kashmir
# 7. Goa
# 8. Masinagudi, Tamil Nadu
# 9. Gulmarg, Jammu & Kashmir
#
# Popular food options for couples in India:
#
# 1. Seafood in Goa
# 2. Momos and Thukpa in Sikkim
# 3. Kawah in Kashmir
# 4. Chole Bhature in North India
# 5. Dosas and Idlis in South India
# 6. Biryani in Hyderabad
# 7. Litti Chokha in Bihar
# 8. Pitha in Assam
# 9. Vada Pav in Mumbai
#
# Recommended itinerary:
#
# 1. Kanyakumari, Tamil Nadu - Enjoy sunsets, full-moon sightings, Tsomgo Lake, Nathu La Pass, Tiger Hill, and tea gardens.
# 2. Manali, India - Experience romantic drives and breathtaking views.
# 3. Jammu & Kashmir - Visit Kashmir Valley for regal charm and breathtaking landscapes.
# 4. Gangtok - Explore Ban Jhakri Falls Park, Gangtok Ropeway, Jawaharlal Nehru Botanical Garden, Sikkim Himalayan Zoological Park, and M.G. Marg.
# 5. Tawang - Visit Sela Pass, Madhuri Lake, Tawang Buddhist Monastery, and Nuranang Falls.
# 6. Kerala - Explore backwaters and beaches.
# 7. Coorg, Karnataka - Go on a special jungle safari.
# 8. Lakshadeep - Enjoy lush greenery, tranquil lagoons, and sun-drenched beaches.
#
# Food options by region:
#
# 1. Kashmiri cuisine in Jammu & Kashmir
# 2. Tibetan and Chinese cuisine in Tawang
# 3. Seafood in Kerala's backwaters
# 4. Spicy pork curries and bamboo shoot dishes in Coorg
# 5. Traditional Indian and Arabic cuisine in Lakshadeep
#
# Land Package for Honeymoon: Starting from INR 10,000 per person.
#
# Popular cafes and restaurants:
#
# 1. Koi Bar, St Regis, Lower Parel (Mumbai)
# 2. The Fisherman's Wharf, Goa
# 3. The Flying Elephant, Chennai
# 4. La Piazza, New Delhi
# 5. Baluchi, New Delhi
# 6. Savannah Bar, Mumbai
# 7. Ambrai Restaurant, Udaipur
# 8. CIBO House HITEC City, Hyderabad
# 9. Holy Basil, Hyderabad
#
# Romantic getaway options:
#
# 1. Gangtok, Sikkim - 4-day tour
# 2. Darjeeling Gangtok Honeymoon Package (5-night/6-day)
# 3. Darjeeling Gangtok Pelling Tour (6-night/7-day)
#
# Other romantic destinations:
#
# 1. Udaipur, Shimla, Jaipur, Munnar, and Gulmarg
# 2. Goa, Kerala, Rajasthan, the Andaman and Nicobar Islands, and Himachal Pradesh
# 3. Alleppey, Shimla & Munnar, and Pondicherry
#
# Food options by location:
#
# 1. Sikkimese and Tibetan cuisine in Gangtok
# 2. Fresh seafood and Goan cuisine in Goa
# 3. Traditional dishes like dosa, idli, and vada in Kerala
# 4. Rajasthani thali and laal maas in Rajasthan
# 5. Fresh seafood and local dishes in the Andaman and Nicobar Islands
#  Thought : Use the search tool to look up "romantic places in India" and "famous Indian cuisine for couples."
#   Write search Thought one by one .Write an simple Action for this Thought with correct syntax
# ********************FULL-PROMPT-END********************
#
#
#
# Thought 1: Use the search tool to look up "romantic places in India"
# Action: Search[Romantic places in India]
#
# Thought 2: Use the search tool to look up "famous Indian cuisine for couples"
# Action: Search[Famous Indian cuisine for couples]
# Action Tools Found: (List)  {'Search': 'Romantic places in India'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': 'Famous Indian cuisine for couples'}
# <class 'dict'>
# For couples looking for romantic places in India, several destinations are worth considering. Kanyakumari, located in Tamil Nadu, offers a stunning view of the sunset and the moon rising, particularly during Chitra Pournami. Agra, home to the Taj Mahal, is a reminder of the Mughal era and a popular honeymoon destination. Nainital, a hill station in Uttarakhand, is known for its scenic landscapes and serene lakes, making it an ideal place for couples looking for a relaxed vacation.
#
# Leh, located in Jammu and Kashmir, is known for its rustic mountains, lakes, Buddhist culture, and monasteries. It is accessible by air, and a land package for honeymoon starts from INR 10,000 per person. Couples can take a romantic stroll in the tea gardens, hike to Tiger Hill, and visit Tsomgo Lake and Nathu La Pass.
#
# Manali, located in Himachal Pradesh, is a popular honeymoon destination, with a scenic drive being one of the top experiences. Other romantic places in India include Andaman & Nicobar Islands, Udaipur, Kerala's backwaters, and Shimla. The Kodagu region of Karnataka, known as Coorg, is renowned for its coffee plantations and stunning scenic beauty.
#
# Overall, India has many romantic spots that are perfect for couples looking for a dreamy escape. Romantic Places in India:
# No specific information found.
#
# Famous Indian Cuisine for Couples:
#
# 1. Biryani: Aromatic mixed rice dish with meat or vegetables, originating from Persia and the Mughals. It varies throughout India.
# 2. Chana Masala: A popular vegetarian dish with chickpeas, tomatoes, onions, garlic, ginger, chilis, and spices.
# 3. Chicken Tikka Masala: A dish resulting from the smoky flavors of Tandoori chicken, with a marinade of spices and yogurt.
# 4. Papdi Chaat: A popular Indian street food with crispy fried dough wafers, boiled chickpeas, potatoes, yogurt, chutneys, and spices.
# 5. Aloo Tikki: A popular appetizer of spiced potato patties, often served with chutneys.
# 6. Chole Bature: A Northern Indian favorite, featuring spicy chickpeas and puffed white flour bread.
# 7. Dal-Baati-Churma: A Rajasthani dish of dal (spicy lentils) served with baati (puffed bread) and churma (crushed bread with sugar and ghee).
# 8. Jalebi: A popular sweet snack, jalebi is a deep-fried flour batter soaked in sugar syrup.
# 9. Rogan Josh: A Kashmiri dish of braised lamb chunks cooked with onions, yogurt, garlic, ginger, and aromatic spices.
#
# Please note that there is no specific connection made between these dishes and romantic settings or couples in the provided text.
# ------------ITEARATION 2------------------
# Token Length:  845
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#  A client plans a 10-day India vacation with a $4000 budget. This summary provides information on romantic places and food options for their itinerary.
#
# Romantic places in India include:
# 1. Kanyakumari, Tamil Nadu
# 2. Gangtok, Sikkim
# 3. Andaman & Nicobar
# 4. Nainital, Uttarakhand
# 5. Manali, Himachal Pradesh
# 6. Jammu & Kashmir
# 7. Goa
# 8. Masinagudi, Tamil Nadu
# 9. Gulmarg, Jammu & Kashmir
#
# Recommended itinerary:
# 1. Kanyakumari - Enjoy sunsets, full-moon sightings, and Tsomgo Lake.
# 2. Manali - Experience romantic drives and breathtaking views.
# 3. Jammu & Kashmir - Visit Kashmir Valley for regal charm and landscapes.
# 4. Gangtok - Explore Ban Jhakri Falls Park, Gangtok Ropeway, and M.G. Marg.
# 5. Tawang - Visit Sela Pass, Tawang Buddhist Monastery, and Nuranang Falls.
# 6. Kerala - Explore backwaters and beaches.
# 7. Coorg, Karnataka - Go on a special jungle safari.
# 8. Lakshadeep - Enjoy lush greenery, tranquil lagoons, and sun-drenched beaches.
#
# Popular food options for couples in India:
# 1. Seafood in Goa
# 2. Momos and Thukpa in Sikkim
# 3. Kawah in Kashmir
# 4. Chole Bhature in North India
# 5. Dosas and Idlis in South India
# 6. Biryani in Hyderabad
# 7. Litti Chokha in Bihar
# 8. Pitha in Assam
# 9. Vada Pav in Mumbai
#
# Food options by region:
# 1. Kashmiri cuisine in Jammu & Kashmir
# 2. Tibetan and Chinese cuisine in Tawang
# 3. Seafood in Kerala's backwaters
# 4. Spicy pork curries and bamboo shoot dishes in Coorg
# 5. Traditional Indian and Arabic cuisine in Lakshadeep
#
# Additional romantic destinations:
# 1. Udaipur, Shimla, Jaipur, Munnar, and Gulmarg
# 2. Goa, Kerala, Rajasthan, the Andaman and Nicobar Islands, and Himachal Pradesh
# 3. Alleppey, Shimla & Munnar, and Pondicherry
#
# Popular cafes and restaurants:
# 1. Koi Bar, St Regis, Lower Parel (Mumbai)
# 2. The Fisherman's Wharf, Goa
# 3. The Flying Elephant, Chennai
# 4. La Piazza, New Delhi
# 5. Baluchi, New Delhi
# 6. Savannah Bar, Mumbai
# 7. Ambrai Restaurant, Udaipur
# 8. CIBO House HITEC City, Hyderabad
# 9. Holy Basil, Hyderabad
#
# Land Package for Honeymoon: Starting from INR 10,000 per person.
#
# Note: No specific information connects particular dishes with romantic settings or couples in the provided text.
#  Thought : Make a list of the top romantic places and Indian food options that I find in the search results.
#   Write search Thought one by one .Write an simple Action for this Thought with correct syntax
# ********************FULL-PROMPT-END********************
#
#
#
# Thought 1: First, I need to find more information about the romantic places in India.
# Action: Search [Romantic places in India detailed information]
#
# Thought 2: Second, I need to find the average cost of activities and accommodations in each of these romantic places.
# Action: Search [Average cost of activities and accommodations in Kanyakumari, Tamil Nadu]
# (Repeat this action for each of the romantic places in the list)
#
# Thought 3: Third, I need to find the average cost of popular food options in each of these romantic places.
# Action: Search [Average cost of seafood in Goa]
# (Repeat this action for each of the popular food options in the list)
#
# Thought 4: Fourth, I need to find the contact information of hotels and restaurants in these romantic places that offer honeymoon packages.
# Action: Search [Honeymoon packages in St Regis, Lower Parel, Mumbai]
# (Repeat this action for each of the popular cafes and restaurants in the list)
#
# Thought 5: Fifth, I need to find the availability and cost of transportation between these romantic places.
# Action: Search [Cost and availability of trains from Kanyakumari to Manali]
# (Repeat this action for each of the transportation options between the romantic places)
# Action Tools Found: (List)  {'Search': 'Romantic places in India detailed information'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': 'Average cost of activities and accommodations in Kanyakumari, Tamil Nadu'}
# <class 'dict'>
# Action Tools Found: (List)  {'for each of the romantic places in the list)\n\nThought 3: Third, I need to find the average cost of popular food options in each of these romantic places.\nAction: Search': 'Average cost of seafood in Goa'}
# <class 'dict'>
# Invalid key. Please use 'Search' or 'Calculate'
# Action Tools Found: (List)  {'for each of the popular food options in the list)\n\nThought 4: Fourth, I need to find the contact information of hotels and restaurants in these romantic places that offer honeymoon packages.\nAction: Search': 'Honeymoon packages in St Regis, Lower Parel, Mumbai'}
# <class 'dict'>
# Invalid key. Please use 'Search' or 'Calculate'
# Action Tools Found: (List)  {'for each of the popular cafes and restaurants in the list)\n\nThought 5: Fifth, I need to find the availability and cost of transportation between these romantic places.\nAction: Search': 'Cost and availability of trains from Kanyakumari to Manali'}
# <class 'dict'>
# Invalid key. Please use 'Search' or 'Calculate'
# sequence item 2: expected str instance, NoneType found
# ------------ITEARATION 3------------------
# Token Length:  368
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#  Client plans a 10-day India vacation with a $4000 budget. This summary focuses on romantic places and food options:
#
# Romantic places in India:
# 1. Kanyakumari, Tamil Nadu
# 2. Gangtok, Sikkim
# 3. Andaman & Nicobar
# 4. Nainital, Uttarakhand
# 5. Manali, Himachal Pradesh
# 6. Jammu & Kashmir
# 7. Goa
# 8. Masinagudi, Tamil Nadu
# 9. Gulmarg, Jammu & Kashmir
#
# Recommended itinerary:
# 1. Kanyakumari - sunsets, full-moon sightings, Tsomgo Lake
# 2. Manali - romantic drives, breathtaking views
# 3. Jammu & Kashmir - Kashmir Valley
# 4. Gangtok - Ban Jhakri Falls Park, Gangtok Ropeway, M.G. Marg
# 5. Tawang - Sela Pass, Tawang Buddhist Monastery, Nuranang Falls
# 6. Kerala - backwaters, beaches
# 7. Coorg, Karnataka - jungle safari
# 8. Lakshadeep - lush greenery, lagoons, beaches
#
# Popular food options:
# 1. Seafood in Goa
# 2. Momos and Thukpa in Sikkim
# 3. Kawah in Kashmir
# 4. Chole Bhature in North India
# 5. Dosas and Idlis in South India
# 6. Biryani in Hyderabad
# 7. Litti Chokha in Bihar
# 8. Pitha in Assam
# 9. Vada Pav in Mumbai
#
# Food options by region:
# 1. Kashmiri cuisine in Jammu & Kashmir
# 2. Tibetan and Chinese cuisine in Tawang
# 3. Seafood in Kerala's backwaters
# 4. Spicy pork curries and bamboo shoot dishes in Coorg
# 5. Traditional Indian and Arabic cuisine in Lakshadeep
#
# Additional romantic destinations:
# 1. Udaipur, Shimla, Jaipur, Munnar, and Gulmarg
# 2. Goa, Kerala, Rajasthan, the Andaman and Nicobar Islands, and Himachal Pradesh
# 3. Alleppey, Shimla & Munnar, and Pondicherry
#
# Land Package for Honeymoon: Starting from INR 10,000 per person.
#
# Note: No specific connection between dishes and romantic settings or couples in the provided text.
#  Thought : Next, search for general travel information and budget-friendly options in India, using search terms like "10-day itinerary in India" and "budget travel tips for India."
#   Write search Thought one by one .Write an simple Action for this Thought with correct syntax
# ********************FULL-PROMPT-END********************
#
#
#
# Thought 1: I need to find a 10-day itinerary in India that fits the client's budget of $4000.
# Action: Search["10-day itinerary in India under $4000"]
#
# Thought 2: I should also look for general budget travel tips for India to further optimize the itinerary.
# Action: Search["budget travel tips for India"]
#
# These actions will help me create a suitable 10-day itinerary for the client while keeping their budget in mind.
# Action Tools Found: (List)  {'Search': '"10-day itinerary in India under $4000"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"budget travel tips for India"'}
# <class 'dict'>
# Title: 10-Day Itinerary in India: Exploring the Beauty of India on a Budget
#
# 1. Begin your journey in the capital city, Delhi. Visit historical sites like the Red Fort and Jama Masjid. Use public transportation to get around and try local street food for affordable meals.
#
# 2. Travel to Agra, home of the Taj Mahal. Book a budget-friendly guesthouse near the Taj Mahal to cut down on transportation costs.
#
# 3. From Agra, head to Rajasthan and visit the city of Jaipur, known as the "Pink City." Explore the Amber Fort and Hawa Mahal. Stay in a budget hotel and dine at local eateries.
#
# 4. Next, visit Udaipur, the "City of Lakes." Enjoy a boat ride in Lake Pichola and visit the City Palace. Look for budget accommodations and eat at street stalls.
#
# 5. Travel to Mumbai, the financial capital of India. Visit the Gateway of India and Elephanta Caves. Use local trains and buses for transportation.
#
# 6. In Mumbai, try the local street food like vada pav and pani puri. Visit the bustling markets for shopping.
#
# 7. For the last leg of your trip, head to Goa, known for its beautiful beaches. Stay in a budget guesthouse and enjoy seafood at local shacks.
#
# 8. Use domestic flights or trains to travel between cities to save time and money.
#
# 9. Book flights to India in advance to get the best deals.
#
# 10. Use travel apps for budget-friendly options like hostels, homestays, and local tours.
#
# 11. Always carry local currency (Indian Rupees) for small purchases and transportation.
#
# 12. Respect local customs and dress modestly, especially when visiting religious sites.
#
# 13. Stay hydrated and carry hand sanitizer and tissues for cleanliness.
#
# 14. Be aware of your surroundings and keep your belongings secure.
#
# 15. Have a flexible itinerary to accommodate any changes or unforeseen circumstances. Looking for budget travel tips for India? Here are some tips to help you save money:
#
# 1. Use a budgeting app to keep track of your spending.
# 2. Check out the top tips and advice for budget travel in India, including transportation and eating out.
# 3. Consider visiting during off-peak times to save on flights and accommodations.
# 4. Take advantage of affordable street food and local markets.
# 5. Look for budget-friendly accommodations such as hostels or guesthouses.
# 6. Use public transportation or walking to get around.
# 7. Consider visiting lesser-known destinations to save on costs.
#
# These tips can help you experience the beauty and culture of India without breaking the bank. For more information, refer to the sources listed.
#
# Sources:
#
# * Budget Travel Tips for India
# * Cultural Trips
# * 7 Top Budget Travel Tips for India
# * Sneha Thomas, October 12, 2023
# * 10 Best Beaches in Goa
# * 7 Budget Travel Tips for India & How Muay Thai Boxing Changed This Digital Nomad's Life
# * Jamie Ditaranto, November 12, 2023
# * Meet Lahé by Loka & Nurall
# * It's the new way to travel
# * Jamie Ditaranto, November 1, 2023
# * 10 Best Beaches in Goa & Our India Visa Guide for Digital Nomads
# * October 22, 2023
# ------------ITEARATION 4------------------
# Token Length:  801
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#  Client plans a 10-day romantic India vacation with a $4000 budget, focusing on places and food options. Romantic places include Kanyakumari, Tamil Nadu; Gangtok, Sikkim; Andaman & Nicobar; Nainital, Uttarakhand; Manali, Himachal Pradesh; Jammu & Kashmir; Goa; Masinagudi, Tamil Nadu; and Gulmarg, Jammu & Kashmir. Recommended itinerary covers Kanyakumari, Manali, Jammu & Kashmir, Gangtok, Tawang, Kerala, Coorg, and Lakshadeep. Popular food options are seafood in Goa, momos and thukpa in Sikkim, kawah in Kashmir, chole bhature in North India, dosas and idlis in South India, biryani in Hyderabad, litti chokha in Bihar, pitha in Assam, and vada pav in Mumbai. Land Package for Honeymoon starts from INR 10,000 per person.
#
# Additional romantic destinations include Udaipur, Shimla, Jaipur, Munnar, and Gulmarg; Goa, Kerala, Rajasthan, the Andaman and Nicobar Islands, and Himachal Pradesh; Alleppey, Shimla & Munnar, and Pondicherry.
#
# For budget travel, consider a 10-day itinerary covering Delhi, Agra, Jaipur, Udaipur, Mumbai, and Goa. Use public transportation, local street food, budget-friendly guesthouses, and travel apps for cost-effective options. Always respect local customs and carry local currency.
#
# Tips for budget travel in India:
#
# 1. Use a budgeting app.
# 2. Visit during off-peak times.
# 3. Take advantage of street food and local markets.
# 4. Look for budget-friendly accommodations.
# 5. Use public transportation or walking.
# 6. Consider visiting lesser-known destinations.
#
# Sources: Budget Travel Tips for India, Cultural Trips, 7 Top Budget Travel Tips for India, Sneha Thomas, October 12, 2023; 10 Best Beaches in Goa; Jamie Ditaranto, November 12, 2023; Meet Lahé by Loka & Nurall; 10 Best Beaches in Goa & Our India Visa Guide for Digital Nomads, October 22, 2023.
#  Thought : Consider the client's budget of $4000 and the costs of travel, accommodations, and activities at the romantic locations. Make sure to find cost-effective options that fit within their budget.
#   Write search Thought one by one .Write an simple Action for this Thought with correct syntax
# ********************FULL-PROMPT-END********************
#
#
#
# Thought 1: What is the average cost of travel, accommodations, and activities in each of the romantic locations?
# Action: Search["Average cost of travel, accommodations, and activities in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"]
#
# Thought 2: What are the cost-effective options for travel, accommodations, and activities in each of the romantic locations?
# Action: Search["Cost-effective options for travel, accommodations, and activities in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"]
#
# Thought 3: What are the budget-friendly accommodations available in each of the romantic locations?
# Action: Search["Budget-friendly accommodations in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"]
#
# Thought 4: What are the local transportation options available in each of the romantic locations?
# Action: Search["Local transportation options in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"]
#
# Thought 5: What are the popular street food and local market options available in each of the romantic locations?
# Action: Search["Popular street food and local market options in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"]
#
# Thought 6: What are the lesser-known romantic destinations within the client's travel itinerary that could save on costs?
# Action: Search["Lesser-known romantic destinations in Kanyakumari, Manali, Jammu & Kashmir, Gangtok, Tawang, Kerala, Coorg, and Lakshadeep"]
# Action Tools Found: (List)  {'Search': '"Average cost of travel, accommodations, and activities in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"Cost-effective options for travel, accommodations, and activities in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"Budget-friendly accommodations in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"Local transportation options in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"Popular street food and local market options in Kanyakumari" + "&" + "Manali" + "&" + "Jammu & Kashmir" + "&" + "Gangtok" + "&" + "Tawang" + "&" + "Kerala" + "&" + "Coorg" + "&" + "Lakshadeep"'}
# <class 'dict'>
# Action Tools Found: (List)  {'Search': '"Lesser-known romantic destinations in Kanyakumari, Manali, Jammu & Kashmir, Gangtok, Tawang, Kerala, Coorg, and Lakshadeep"'}
# <class 'dict'>
# After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations and cost-effective options within the client's budget of $4000, I have found the following summarized information:
#
# 1. San Diego, California:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $1200-$1500 for 4-star hotels for 4 nights
# - Activities:
# -- Balboa Park: Free entry, $50 for activities
# -- San Diego Zoo: $100 for two
# -- Harbor cruise: $60 for two
# - Total cost: $2760-$3260, leaving room for meals and additional activities.
#
# 2. Charleston, South Carolina:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $1000-$1200 for 4-star hotels for 4 nights
# - Activities:
# -- Carriage tour: $70 for two
# -- Historic homes tour: $30 per person
# -- Plantation tour: $60 for two
# - Total cost: $1840-$2040, also leaving room for meals and additional activities.
#
# 3. Savannah, Georgia:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $900-$1100 for 4-star hotels for 4 nights
# - Activities:
# -- Trolley tour: $40 for two
# -- Historic homes tour: $20 per person
# -- Tybee Island day trip: $40 for transportation and beach activities
# - Total cost: $1480-$1780, leaving room for meals and additional activities.
#
# These cost-effective options provide a balance between travel, accommodations, and activities, fitting within the client's budget of $4000.
# ------------ITEARATION 5------------------
# Token Length:  1410
# ********************FULL-PROMPT-START********************
#
# You were an assistant to the manager at AGNOS Travel Agency which have many clients; previously, he gave you tasks and multiple thoughts, which you performed perfectly. Now he gave you the most important task and thoughts. You need to respond to the thoughts carefully and correctly, as your promotion is in his hands.
#
# He said to use only these Tools: Search[Text to search in the internet or URL], Calculator[Expression or numbers to calculate]
# Previous Task: I want a detailed analysis report of Competators of Luxury shoe market for investors to launch my new shoe brand
# Thought 1: First I need to find, which companies work in luxury shoe market
# Observation: "The most expensive shoe brand in the world is reportedly Stuart Weitzman, who designed a pair of shoes valued at $3 million. Jimmy Choo shoes range in price from $395 to $4,595. Alexander McQueen shoes start at a price point of $620. Valentino's shoe collection starts at a price point of $845.Feb 7, 2024"
# Thought 2: Second, Make a list of all the companies
# 1. Stuart Weitzman
# 2. Jimmy Choo shoes
# 3. Alexander McQueen
# 4. Valentino shoe
# Thought 3: Third, Now search which products, Number of products.
# Action: Search[Stuart Weitzman shoes all products]
#
# Completed.
#
#
#  Client plans a romantic 10-day India vacation with a $4000 budget, focusing on places and food. Recommended itinerary covers Kanyakumari, Manali, Jammu & Kashmir, Gangtok, Tawang, Kerala, Coorg, and Lakshadeep. Popular food options include seafood in Goa, momos and thukpa in Sikkim, kawah in Kashmir, chole bhature in North India, dosas and idlis in South India, biryani in Hyderabad, litti chokha in Bihar, pitha in Assam, and vada pav in Mumbai. Land Package for Honeymoon starts from INR 10,000 per person.
#
# Budget travel tips include using a budgeting app, visiting during off-peak times, taking advantage of street food and local markets, looking for budget-friendly accommodations, using public transportation or walking, and considering visiting lesser-known destinations.
#
# Cost-effective romantic location options within the client's budget of $4000:
#
# 1. San Diego, California:
# ...
#
# Please note that there is no specific connection made between these dishes and romantic settings or couples in the provided text. Title: 10-Day Itinerary in India: Exploring the Beauty of India on a Budget
#
# 1. Begin your journey in the capital city, Delhi. Visit historical sites like the Red Fort and Jama Masjid. Use public transportation to get around and try local street food for affordable meals.
#
# 2. Travel to Agra, home of the Taj Mahal. Book a budget-friendly guesthouse near the Taj Mahal to cut down on transportation costs.
#
# 3. From Agra, head to Rajasthan and visit the city of Jaipur, known as the "Pink City." Explore the Amber Fort and Hawa Mahal. Stay in a budget hotel and dine at local eateries.
#
# 4. Next, visit Udaipur, the "City of Lakes." Enjoy a boat ride in Lake Pichola and visit the City Palace. Look for budget accommodations and eat at street stalls.
#
# 5. Travel to Mumbai, the financial capital of India. Visit the Gateway of India and Elephanta Caves. Use local trains and buses for transportation.
#
# 6. In Mumbai, try the local street food like vada pav and pani puri. Visit the bustling markets for shopping.
#
# 7. For the last leg of your trip, head to Goa, known for its beautiful beaches. Stay in a budget guesthouse and enjoy seafood at local shacks.
#
# 8. Use domestic flights or trains to travel between cities to save time and money.
#
# 9. Book flights to India in advance to get the best deals.
#
# 10. Use travel apps for budget-friendly options like hostels, homestays, and local tours.
#
# 11. Always carry local currency (Indian Rupees) for small purchases and transportation.
#
# 12. Respect local customs and dress modestly, especially when visiting religious sites.
#
# 13. Stay hydrated and carry hand sanitizer and tissues for cleanliness.
#
# 14. Be aware of your surroundings and keep your belongings secure.
#
# 15. Have a flexible itinerary to accommodate any changes or unforeseen circumstances. Looking for budget travel tips for India? Here are some tips to help you save money:
#
# 1. Use a budgeting app to keep track of your spending.
# 2. Check out the top tips and advice for budget travel in India, including transportation and eating out.
# 3. Consider visiting during off-peak times to save on flights and accommodations.
# 4. Take advantage of affordable street food and local markets.
# 5. Look for budget-friendly accommodations such as hostels or guesthouses.
# 6. Use public transportation or walking to get around.
# 7. Consider visiting lesser-known destinations to save on costs.
#
# These tips can help you experience the beauty and culture of India without breaking the bank. For more information, refer to the sources listed.
#
# Sources:
#
# * Budget Travel Tips for India
# * Cultural Trips
# * 7 Top Budget Travel Tips for India
# * Sneha Thomas, October 12, 2023
# * 10 Best Beaches in Goa
# * 7 Budget Travel Tips for India & How Muay Thai Boxing Changed This Digital Nomad's Life
# * Jamie Ditaranto, November 12, 2023
# * Meet Lahé by Loka & Nurall
# * It's the new way to travel
# * Jamie Ditaranto, November 1, 2023
# * 10 Best Beaches in Goa & Our India Visa Guide for Digital Nomads
# * October 22, 2023 After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations within the client's budget of $4000, I have found some cost-effective options:
#
# 1. San Diego, California: Affordable flights and accommodations can be found, with many romantic activities available such as beach visits, walks along the harbor, and visits to Balboa Park.
#
# 2. Asheville, North Carolina: This location offers scenic views and a variety of activities, such as hiking and visiting the Biltmore Estate. Accommodations and travel costs are within budget.
#
# 3. Portland, Maine: A charming and romantic location with a lower cost of living. Activities include visiting lighthouses, exploring the Old Port, and enjoying fresh seafood.
#
# 4. San Juan, Puerto Rico: Offers a tropical getaway with beautiful beaches and historic sites. Flights and accommodations can be found within budget.
#
# 5. Santa Fe, New Mexico: Known for its art scene and Pueblo-style architecture, this location offers a unique romantic experience. Costs for travel and accommodations are within the client's budget.
#
# Please note that prices are subject to change and should be verified for accuracy. It is recommended to book in advance to secure the best deals. After conducting web research on romantic locations and cost-effective options within the client's budget of $4000, I have found the following summarized information:
#
# 1. San Diego, California:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $1200-$1500 for 4-star hotels for 4 nights
# - Activities:
# -- Balboa Park: Free entry, $50 for activities
# -- San Diego Zoo: $100 for two
# -- Harbor cruise: $60 for two
# - Total cost: $2760-$3260, leaving room for meals and additional activities.
#
# 2. Charleston, South Carolina:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $1000-$1200 for 4-star hotels for 4 nights
# - Activities:
# -- Carriage tour: $70 for two
# -- Historic homes tour: $30 per person
# -- Plantation tour: $60 for two
# - Total cost: $1840-$2040, also leaving room for meals and additional activities.
#
# 3. Savannah, Georgia:
# - Roundtrip flights for two: $400-$600
# - Accommodations: $900-$1100 for 4-star hotels for 4 nights
# - Activities:
# -- Trolley tour: $40 for two
# -- Historic homes tour: $20 per person
# -- Tybee Island day trip: $40 for transportation and beach activities
# - Total cost: $1480-$1780, leaving room for meals and additional activities.
#
# These cost-effective options provide a balance between travel, accommodations, and activities, fitting within the client's budget of $4000. Itinerary for a romantic 10-day trip to San Diego:
#
# Day 1:
#
# * Stroll through Balboa Park in the evening and enjoy the sunset
#
# Day 2:
#
# * Hike the trails at Torrey Pines State Reserve
# * Fine dining with views of Torrey Pines Golf Course ($175 per person or $250 with wine pairings)
#
# Day 3:
#
# * Book a Beach Roast at Hotel del Coronado
# * Spend the night in a romantic hotel
#
# Day 4:
#
# * Visit the historic Carousels and surf-side dining in Mission Beach
# * Explore Sunny Jim's Sea Cave in La Jolla
#
# Day 5:
#
# * Spend the day at Coronado Island
# * Take a tour of the caves and caverns
#
# Day 6:
#
# * Visit the Gaslamp Quarter
# * Enjoy the charm of the historic district
#
# Day 7:
#
# * Visit the USS Midway Museum
# * Have dinner in Little Italy
#
# Day 8:
#
# * Spa day at Pendry San Diego
# * Romantic couple's retreat with massages and rose foot bath
#
# Day 9:
#
# * Visit the San Diego Zoo
# * Have dinner at Born and Raised
#
# Day 10:
#
# * Visit the Farmers Market in Little Italy
# * Take a scenic drive along the coast
#
# Tips:
#
# * Book in advance for popular restaurants and activities
# * Consider purchasing the Go San Diego Card for discounts on attractions
# * Use public transportation or rideshare services to get around
# * Check for any special events or festivals happening during your visit. Itinerary for a 10-day trip to San Diego:
#
# Day 1:
#
# * Visit The Smoking Goat restaurant for upscale dining and craft cocktails.
# * Try their fresh oysters and carne asada fries.
#
# Day 2:
#
# * Have dinner at Buona Forchetta for authentic Neapolitan pizza.
# * Participate in the pizza-making class and receive a complimentary T-shirt.
#
# Day 3:
#
# * Try Tuetano Taqueria for traditional Mexican cuisine.
# * Order their signature dish - tuetano (beef marrow) tacos.
#
# Day 4:
#
# * Visit Bok Bok Dok for Korean-style bulgogi.
# * Try their rice bowls or wraps with Korean BBQ beef.
#
# Day 5:
#
# * Dine at Ciccia Osteria for Italian cuisine in Barrio Logan.
# * Enjoy their homemade pasta and seafood dishes.
#
# Day 6:
#
# * Explore Filipino cuisine at one of the many Filipino-American restaurants in the area.
# * Try progressive takes on classic dishes at Animae, White Rice, or Market on 8th.
#
# Day 7:
#
# * Try Japanese ramen at one of San Diego's many ramen shops.
# * Visit Ramen Yamadaya, Underbelly, or Tajima for authentic ramen.
#
# Day 8:
#
# * Visit Barrio Dogg for low-rider-themed hot dogs and tasty toppings.
# * Try their Xolito dog or rolled tacos.
#
# Day 9:
#
# * Try seafood at one of San Diego's many waterfront restaurants.
# * Visit The Fish Market, Top of the Market, or Island Prime for fresh seafood.
#
# Day 10:
#
# * Visit Little Italy Mercato farmers market for local produce and artisanal foods.
# * Try some of the many food stalls and vendors for a taste of San Diego's diverse food scene.
#
# Travel Tips:
#
# * Use public transportation or rideshare services to get around the city.
# * Take advantage of San Diego's many outdoor activities and scenic views.
# * Use credit cards that offer rewards or cashback for dining and travel expenses.
# * Be mindful of the budget and try to balance expensive meals with more affordable options. Itinerary for a 10-day trip to San Diego for a couple on a budget:
#
# Day 1: Check-in at Gorgeous Pacific Beach and Mission Bay Home, a budget-friendly accommodation.
#
# Day 2-3: Explore Pacific Beach, visit the Bay and Golf Course, and try out local food options.
#
# Day 4: Move to Downtown San Diego/Little Italy and check-in at Hilton Garden Inn San Diego Downtown/Bayside or Homewood Suites San Diego Downtown/Bayside.
#
# Day 5-6: Visit popular attractions in Downtown San Diego and Little Italy, such as the USS Midway Museum and the San Diego Public Library.
#
# Day 7: Travel to Del Mar Beach and stay at Del Mar Beach Hotel, a budget-friendly beachfront motel.
#
# Day 8-9: Enjoy the beach, visit the Del Mar Fairgrounds, and explore local shops and restaurants.
#
# Day 10: Check-out and move to Ramada Gaslamp Convention Center-The Historic St James Hotel for the last night.
#
# Additional tips:
# -Consider staying at budget-friendly hotels such as Best Western Yacht Harbor Hotel, Courtyard San Diego Airport/Liberty Station, or Lucky D's Hostel.
# -Take advantage of self-catering accommodation options like Stay Classy and Ith Beach Bungalow Surf Hostel San Diego.
# -Use Tripadvisor to read reviews and compare prices of different hotels and accommodations.
# -Plan meals at budget-friendly restaurants and consider self-catering options.
# -Utilize public transportation and walking to get around the city. Day 3 in San Diego itinerary:
#
# 1. Start the day with a run in Torrey Pines State Park.
# 2. Visit La Jolla and enjoy the beaches.
# 3. Check out the Geisel Library.
# 4. Head to Pacific Beach.
#
# Other recommendations:
#
# 1. Mission Bay Park is a must-visit for water sports and outdoor activities.
# 2. Consider getting a Balboa Park Pass for museum visits.
# 3. Check out the annual Flower Show in Coronado and Cinco de Mayo festivities.
# 4. The average food cost in San Diego is $45 per day, with an average meal cost of $18 per person.
# 5. There are many free activities and attractions in San Diego, including beaches, bays, and historic buildings.
# 6. Consider hiking Torrey Pines State Natural Reserve for stunning views.
#
# Budgeting tips:
#
# 1. It's possible to visit San Diego on a budget by staying in affordable accommodations, visiting free attractions, and dining at inexpensive restaurants.
# 2. Look for deals on tickets for Sea World and the San Diego Zoo.
# 3. Plan meals carefully to stay within the daily food budget of $45 per day.
# 4. Take advantage of free activities, such as hiking and visiting parks.
# ===================END========================

# %%
def save_file(content, filename):

    with open(filename, 'w') as f:
        f.write(content)

import re

def extract_text_between_tags(text, start_tag, end_tag):
    pattern = re.compile(rf"{re.escape(start_tag)}(.*?){re.escape(end_tag)}", re.DOTALL)
    match = pattern.search(text)
    if match:
        return match.group(1)
    return None



markdown_html_prompt = f"""
Convert this markdown to full HTML code, and connect styles.css
Start your response with [HTML] and write the whole html code and end the code with [/HTML] tags:

{Markdown_full_text}
"""
html_resp = O_LLM(markdown_html_prompt)

start_tag = "[HTML]"
end_tag = "[/HTML]"

extracted_html_text = extract_text_between_tags(html_resp, start_tag, end_tag)
print(extracted_html_text)

#---------------------------------------------------------------------------------------------------------------------------


html_css_prompt = f"""
Write a styles.css for this HTML code, make it look stunning, with some design and make the text 'Dark' color 'Sans-Serif' and font size 10.
Add borders some length. make background white gradient with individual sections seperation. start your response with [css] and end with [/css]:

{extracted_html_text}

"""
css_resp = O_LLM(html_css_prompt)


start_tag = "[css]"
end_tag = "[/css]"

extracted_text = extract_text_between_tags(css_resp, start_tag, end_tag)
print(extracted_text)



html_path = r"C:\Users\akhil\Downloads\html_india.html"
save_file(extracted_html_text, html_path)



css_path1 =  r"C:\Users\akhil\Downloads\styles.css"
save_file(extracted_text, css_path1)

# css_path2 =  r"C:\Users\akhil\Downloads\styles2.css"
# save_file(css_styles2, css_path2)
# Out:
# <html>
# <head>
#     <title>Romantic Getaways in India</title>
#     <link rel="stylesheet" type="text/css" href="styles.css">
# </head>
# <body>
#     <h1>Romantic Getaways in India</h1>
#     <p>For a couples' vacation in India, popular romantic places include:</p>
#     <ol>
#         <li>Kanyakumari, Tamil Nadu - known for its stunning sunsets and full-moon sightings.</li>
#         <li>Gangtok, Sikkim - offering a variety of tour packages for couples.</li>
#         <li>Andaman & Nicobar - famous for its serene beaches and water sports activities.</li>
#         <li>Nainital, Uttarakhand - with pleasant weather and scenic landscapes.</li>
#         <li>Manali, Himachal Pradesh - offering romantic drives and breathtaking views.</li>
#         <li>Jammu & Kashmir - a hot spot for romantic getaways with serene lakes and scenic landscapes.</li>
#         <li>Goa - known for its hippy culture, incredible cuisine, and exotic beaches.</li>
#         <li>Masinagudi, Tamil Nadu - offering wilderness retreats and exhilarating getaways.</li>
#         <li>Gulmarg, Jammu & Kashmir - an ideal setting for couples seeking a cosy winter retreat.</li>
#     </ol>
#     <h2>Popular Food Options for Couples in India:</h2>
#     <ol>
#         <li>Seafood in Goa.</li>
#         <li>Momos and Thukpa in Sikkim.</li>
#         <li>Kawah in Kashmir.</li>
#         <li>Chole Bhature in North India.</li>
#         <li>Dosas and Idlis in South India.</li>
#         <li>Biryani in Hyderabad.</li>
#         <li>Litti Chokha in Bihar.</li>
#         <li>Pitha in Assam.</li>
#         <li>Vada Pav in Mumbai.</li>
#     </ol>
#     <p>For a memorable couples' vacation in India, consider visiting these romantic places and trying out these delicious food options!</p>
# </body>
# </html>
#
#
# body {
#  background: linear-gradient(white, lightgray);
#  font-family: 'Sans-Serif';
# }
#
# h1, h2 {
#  color: dark;
# }
#
# h1 {
#  text-align: center;
#  padding: 20px;
#  margin-bottom: 40px;
#  border-bottom: 5px solid dark;
# }
#
# h2 {
#  text-align: center;
#  padding: 20px;
#  margin-top: 40px;
#  border-top: 5px solid dark;
# }
#
# p {
#  text-align: justify;
#  padding: 0 20px;
# }
#
# ol {
#  padding: 0 20px;
# }
#
# li {
#  margin-bottom: 10px;
#  border-bottom: 1px solid lightgray;
#  padding-bottom: 5px;
# }

# %%
print(extracted_html_text)
# Out:
# <html>
# <head>
#     <title>Romantic Germany: A Guide for Couples</title>
#     <link rel="stylesheet" type="text/css" href="styles1.css">
#     <link rel="stylesheet" type="text/css" href="styles2.css">
# </head>
# <body>
#     <h1>Romantic Germany: A Guide for Couples</h1>
#     <h2>Romantic Places in Germany</h2>
#     <p>For a romantic vacation in Germany, consider the following:</p>
#     <ul>
#         <li>Hohenzollern Bridge in Cologne: Hang a love lock on this bridge as a symbol of eternal love.</li>
#         <li>Berchtesgadener Land: Experience togetherness in this area known for its gentle Alpine slopes.</li>
#         <li>Mainau Island on Lake Constance: A perfect spot for taking beautiful pictures of your romantic trip.</li>
#     </ul>
#     <h2>Romantic Food in Germany</h2>
#     <p>Germany is known for its hearty and delicious cuisine. Some popular romantic foods include:</p>
#     <ul>
#         <li>Schnitzel: A breaded and fried cutlet, usually made from veal or pork.</li>
#         <li>Sauerbraten: A pot roast, usually of beef, marinated before being slow-cooked.</li>
#         <li>Spätzle: Soft egg noodles, often served as a side dish or mixed with cheese.</li>
#         <li>Black Forest Gateau: A rich, chocolate sponge cake with whipped cream and cherries.</li>
#     </ul>
#     <h2>Romantic Places in Germany</h2>
#     <ul>
#         <li>Neuschwanstein Castle, Bavaria: This 19th-century Romanesque Revival palace is one of the most famous landmarks in Germany and a popular honeymoon destination.</li>
#         <li>Rothenburg ob der Tauber, Bavaria: A well-preserved medieval town with cobblestone streets, half-timbered houses, and a town wall that offers a romantic and charming atmosphere.</li>
#         <li>Moselle River: This picturesque river in western Germany is known for its stunning vineyards, charming towns, and romantic cruises.</li>
#         <li>Heidelberg, Baden-Württemberg: A historic city with a romantic old town, Heidelberg Castle, and the Philosophenweg (Philosophers' Walk), offering breathtaking views of the city and the Neckar River.</li>
#         <li>Berlin: The capital city of Germany may not seem like an obvious choice for a romantic getaway, but it offers many romantic spots such as the Tiergarten park, the Spree River, and the beautiful gardens of the Sanssouci Palace in Potsdam.</li>
#     </ul>
#     <h2>Romantic Food in Germany</h2>
#     <ul>
#         <li>Schwarzwälder Kirschtorte (Black Forest Gateau): This rich and decadent chocolate sponge cake with whipped cream and cherries is a popular dessert in Germany and a perfect treat for a romantic occasion.</li>
#         <li>Sauerbraten: A traditional German pot roast made with beef, onions, and a sweet and sour sauce, often served with red cabbage and dumplings or potatoes.</li>
#         <li>Spätzle: A type of egg noodle or dumpling that is a staple in German cuisine, often served as a side dish or as a main course with cheese or mushrooms.</li>
#         <li>Flammkuchen: A thin and crispy pizza-like dish from the Alsace region, topped with crème fraîche, onions, and bacon or other toppings of your choice.</li>
#         <li>Glühwein: A warm and comforting mulled wine made with red wine, spices, and citrus fruits, perfect for sipping on a cold winter night.</li>
#     </ul>
# </body>
# </html>
